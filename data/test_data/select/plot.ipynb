# %%
from pyntcloud import PyntCloud

human_face = PyntCloud.from_file("final_mesh_squirrel.ply")
human_face.add_structure("voxelgrid")
human_face.plot(backend="pyvista", elev=45, azim=45)

# %%
import pyvista as pv
mesh = pv.read("final_mesh_squirrel.ply")
mesh.plot(backend="panel")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FEC00A70910>
